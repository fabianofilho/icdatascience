# %% [markdown]
# # Map

# %%
# !pip install folium

# %%
import folium


m = folium.Map(location=[-20.3222, -40.3381])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[-20.3222, -40.3381],
    zoom_start=12,
    tiles='Stamen Terrain'
)


 # NIVEL 1
    
folium.Marker(
    location=[-20.314636, -40.353172],
    popup='<font color="green"><P ALIGN=CENTER><b>US ALAGOANO</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green'),
).add_to(m)

folium.Marker(
    location=[-20.290400, -40.306522],
    popup='<font color="green"><P ALIGN=CENTER><b>US DE ANDORINHAS</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[-20.295082, -40.308788],
    popup='<font color="green"><P ALIGN=CENTER><b>US DE ITARARÉ</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[-20.296192, -40.316429],
    popup='<font color="green"><P ALIGN=CENTER><b>US MARUÍPE</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[-20.316673, -40.336842],
    popup='<font color="green"><P ALIGN=CENTER><b>US FONTE GRANDE</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[-20.280081, -40.337093],
    popup= '<font color="green"><P ALIGN=CENTER><b>US ILHA DAS CAIEIRAS</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[-20.315302, -40.298615],
    popup= '<font color="green"><P ALIGN=CENTER><b>US PRAIA DO SUÁ</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[-20.293051, -40.300529],
    popup= '<font color="green"><P ALIGN=CENTER><b>US SANTA LUIZA</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)

folium.Marker(
    location=[-20.293024, -40.321136],
    popup= '<font color="green"><P ALIGN=CENTER><b>US SÃO CRISTOVÃO</font><br>(Emescam, Ufes)</P>',
    icon=folium.Icon(color='green')
).add_to(m)



# NIVEL 2

folium.Marker(
    location=[-20.297855, -40.311638],
    popup='<font color="red"><P ALIGN=CENTER><b>US BAIRRO DA PENHA</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.304922, -40.304893],
    popup='<font color="red"><P ALIGN=CENTER><b>US CONSOLAÇÃO</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.255287, -40.269413],
    popup='<b><font color="red"><P ALIGN=CENTER><b>US JARDIM CAMBURI</font><br>(Emescam , Ufes)</P></b>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.285126, -40.297653],
    popup='<font color="red"><P ALIGN=CENTER><b>US JARDIM DA PENHA. </font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.319794, -40.304142],
    popup='<font color="red"><P ALIGN=CENTER><b>US JESUS NAZARETH</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.316332, -40.348961],
    popup='<font color="red"><P ALIGN=CENTER><b>US DO QUADRO</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.318550, -40.324928],
    popup='<font color="red"><P ALIGN=CENTER><b>US FORTE SÃO JOAO</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.321977, -40.349478],
    popup='<font color="red"><P ALIGN=CENTER><b>US ILHA DO PRÍNCIPE</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.257151, -40.298261],
    popup='<font color="red"><P ALIGN=CENTER><b>US MARIA ORTIZ</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.270557, -40.318033],
    popup='<font color="red"><P ALIGN=CENTER><b>US RESISTÊNCIA</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.286525, -40.310324],
    popup='<font color="red"><P ALIGN=CENTER><b>US SANTA MARTHA</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.277978, -40.332402],
    popup='<font color="red"><P ALIGN=CENTER><b>US SANTO ANDRÉ</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.308112, -40.351531],
    popup='<font color="red"><P ALIGN=CENTER><b>US SANTO ANTÔNIO</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.320067, -40.340230],
    popup='<font color="red"><P ALIGN=CENTER><b>US VITÓRIA GENY GRIJÓ</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.314528, -40.299483],
    popup='<font color="red"><P ALIGN=CENTER><b>PA DA PRAIA DO SUÁ</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.284597, -40.332385],
    popup='<font color="red"><P ALIGN=CENTER><b>PA DE SÃO PEDRO</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)



# TO-DO
# NIVEL 3

folium.Marker(
    location=[-20.272455, -40.292033],
    popup='<font color="blue"><P ALIGN=CENTER><b>US BAIRRO REPÚBLICA</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.304135, -40.314593],
    popup='<font color="blue"><P ALIGN=CENTER><b>US BONFIM "THOMAZ TOMASI"</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.260220, -40.294943],
    popup='<font color="blue"><P ALIGN=CENTER><b>US DE JABOUR</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.290184, -40.343971],
    popup='<font color="blue"><P ALIGN=CENTER><b>US GRANDE VITÓRIA</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.313468, -40.316942],
    popup='<font color="blue"><P ALIGN=CENTER><b>US ILHA DE SANTA MARIA</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(icon='info-sign')
).add_to(m)


# NIVEL 4

folium.Marker(
    location=[-20.314829, -40.317637],
    popup='<font color="purple"><P ALIGN=CENTER><b>CENTRO DE ATENÇÃO PSICOSSOCIAL</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.312555, -40.317481],
    popup='<font color="purple"><P ALIGN=CENTER><b>CAPS ÁLCOOL E OUTRAS DROGAS</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.311456, -40.308376],
    popup='<font color="purple"><P ALIGN=CENTER><b>CAPS INFANTIL</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.284780, -40.331560],
    popup='<font color="purple"><P ALIGN=CENTER><b>CAPS SÃO PEDRO</font><br>(Emescam , Ufes)</P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.282768, -40.333041],
    popup='<font color="purple"><P ALIGN=CENTER><b>CENTRO MUNICIPAL DE ESPECIALIDADE DE SÃO PEDRO</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.319245, -40.353778],
    popup='<font color="purple"><P ALIGN=CENTER><b>CENTRO MUNICIPAL DE ESPECIALIDADE VITÓRIA</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.321199, -40.325801],
    popup='<font color="purple"><P ALIGN=CENTER><b>GERENCIA DE ATENÇÃO A SAUDE</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.318193, -40.322185],
    popup='<font color="purple"><P ALIGN=CENTER><b>GERÊNCIA DE VIGILÂNCIA EM SAÚDE</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.314576, -40.289570],
    popup='<font color="purple"><P ALIGN=CENTER><b>LABORATORIO CENTRAL MUNICIPAL</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.318206, -40.322201],
    popup='<font color="purple"><P ALIGN=CENTER><b>SECRETARIA MUNICIPAL DE SAÚDE DE VITÓRIA</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.284771, -40.331587],
    popup='<font color="purple"><P ALIGN=CENTER><b>SERV. ATENÇÃO A PESSOA EM SITUAÇÃO DE VIOLÊNCIA</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.266462, -40.267906],
    popup='<font color="purple"><P ALIGN=CENTER><b>SERVIÇO DE ORIENTAÇÃO AO EXERCÍCIO</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)

folium.Marker(
    location=[-20.311733, -40.315399],
    popup='<font color="purple"><P ALIGN=CENTER><b>UNIDADE DE VIGILÂNCIA SANITÁRIA</font><br></P>',
    icon=folium.Icon(color='purple', icon='info-sign')
).add_to(m)





m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
(2, '', 'Rua Emilio Ferreira da Silva , NIVEL1',, 'bar'),
(3, , 'Rua Doutor Arlindo Sodre, NIVEL1', 'ubs'),
(4, ', 'Rua Victor Fritoli Navarro, NIVEL 1',, 'ubs'),
(5, , 'Rua Graciano Neves, NIVEL 1', , 'ubs'),
(6,, 'Avenida Beira Mar, NIVEL 1', , 'restaurant'),
(7,, 'Rua Caetano Tunholi, Enseada do Sua, NIVEL 1', -20.315302, -40.298615, 'restaurant'),
(8, 'UNIDADE DE SAUDE SANTA LUIZA', 'Rua Doutor Joao Carlos de Souza , NIVEL 1', -20.293051, -40.300529, 'ubs'),
(9, 'UNIDADE DE SAUDE SAO CRISTOVAO', 'Rua Alcides Lyrio do Nascimento, NIVEL 1', -20.293024, -40.321136, 'ubs'),


(11, 'UNIDADE DE SAUDE DE JARDIM CAMBURI', 'nv2', -20.255287, -40.269413, 'bar'),
(12, 'UNIDADE DE SAUDE DE JARDIM DA PENHA', 'Greenwood Plaza, 36 Blue St, North Sydney NSW', -20.285126, -40.297653, 'bar'),
(13, 'UNIDADE DE SAUDE DE JESUS NAZARETH', '7A, 2 Huntley Street, Alexandria, NSW', -20.319794, -40.304142, 'bar'),
(14, 'UNIDADE DE SAUDE BAIRRO DA PENHA, NIVEL2', '', -20.297855, -40.311638, 'bar'),
(15, 'UNIDADE DE SAUDE DO QUADRO', '43 Macpherson Street, Bronte, NSW', -20.316332, -40.348961, 'restaurant'),
(16, 'UNIDADE DE SAÚDE FORTE SÃO JOAO', '60-64 Reservoir Street, Surry Hills, NSW', -20.318550, -40.324928, 'restaurant'),
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f5f98a1e172a> in <module>()
#      16
#      17 folium.TopoJson(
# ---> 18     json.loads(requests.get(antarctic_ice_shelf_topo).text),
#      19     'objects.antarctic_ice_shelf',
#      20     name='topojson'
#
# NameError: name 'json' is not defined

# %%
m.save('index.html')
