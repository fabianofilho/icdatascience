# %% [markdown]
# Importando Pandas

# %%
import pandas as pd
from IPython.core.display import HTML
from IPython.core.display import HTML
pd.set_option('display.max_columns', None)

# %% [markdown]
# Import DBs

# %%
df_sim_es_1 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vR_MH3HjwGWD0icAnZ3LVxxKUIxYNgAE3R-m-P61g0T2iXE9bs3hjeItGKTJqIUslIOAFN7TrE2ghGM/pub?gid=1574877476&single=true&output=csv')
df_sim_es_2 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSQAjV9c7HSRNciS8zQZFtlffe-X0V8Wcc5EAM9wqhVGPHnI3IpAaliYwadmK4nHiKPz9GbXn_-xNNC/pub?gid=817434201&single=true&output=csv')
df_sim_es_3 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRGEAcKThbNaB9Kfp2vdoWZIMjUaVLwDF0Cf9_534xkV2iDWv4SZACgDBG7CnhzjXd_dCvwvadINdL1/pub?gid=1932938775&single=true&output=csv')
df_sim_es_4 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRf-ecv5pdc0k2GR3SBdoCeZtRM6SPjSyQDFVwlUmzd8YsPVWPwZvx3ZnM8y_B5kBcFH-QxYIyTuYzr/pub?gid=1342589125&single=true&output=csv')
df_sim_es_5 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vS9XW4Hxc0QwEENpDDXLIBgDkyaTz89AXhgYYDcw7lHhBRjnLyQ2Y7B77fMV2LVmivKhSABYr-2fcFx/pub?gid=508819616&single=true&output=csv')
df_sim_es = pd.concat([df_sim_es_1, df_sim_es_2, df_sim_es_3, df_sim_es_4, df_sim_es_5])
df_sim_es.head()

df_sinasc_es_1 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQm3T1J0pWoiG-JofcT-K4gvs1KBeKuCqYIxp2ZSvUjbdkzXFCrBd3pxFUqHvRqmg3iIunrxVTYIZRI/pub?gid=2016691083&single=true&output=csv')
df_sinasc_es_2 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQIyzKl_u0t_YN_stW1Nr4VHWw0XY5zdXhqi15RitMcNPQpDZdU5apVR5aOQmbVYu284B4wNJUMonXU/pub?gid=1338898032&single=true&output=csv')
df_sinasc_es_3 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTIPBsiEtG3heF7zGO6HRkVae9PAO_yJI8SVtw2YncAb1JByCTIsFid0rruA7c4Pq8TDCbI3j6LQjMc/pub?gid=580169372&single=true&output=csv')
df_sinasc_es_4 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vROjHq3_oX3W_j6GEVjNBoKdnoUJgE5HGIfyrWnB8mgXikfc15O08SvOVXqmuxfyZmp-lMM3ETsPvkZ/pub?gid=535577998&single=true&output=csv')
df_sinasc_es_5 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRsmVmV6LY0nRKPr6MeqbNmH70iM20lPQdAmq0wNHJCRTxEGBzdM3cxgF6Ovd_mplD4RJ1EtCXBTAd6/pub?gid=1590264663&single=true&output=csv')
df_sinasc_es = pd.concat([df_sinasc_es_1, df_sinasc_es_2, df_sinasc_es_3, df_sinasc_es_4, df_sinasc_es_5])
df_sinasc_es.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    APGAR1  APGAR5 CODANOMAL  CODCART   CODESTAB        CODINST  CODMUNCART  \
# 0     8.0     9.0       NaN      NaN  2507447.0  MBA2910720001         NaN
# 1     9.0    10.0       NaN      NaN  2802112.0  MBA2913600002         NaN
# 2     9.0    10.0       NaN      NaN  2506122.0  MBA2922000001         NaN
# 3    10.0    10.0       NaN      NaN  2506122.0  MBA2922000001         NaN
# 4     8.0     9.0       NaN      NaN  2498804.0  MBA2922000001         NaN
#
#    CODMUNNASC  CODMUNNATU  CODMUNRES  CODOCUPMAE  CODPAISRES  CODUFNATU  \
# 0      291072    291630.0     320500         NaN         1.0       29.0
# 1      291360    291360.0     320520         NaN         1.0       29.0
# ...

# %% [markdown]
# Merges

# %%
df_merged_left = pd.merge(df_sinasc_es, df_sim_es, how='left', on = 'NUMERODN')
df_merged_left.describe()
# Out:
#               APGAR1         APGAR5    CODCART_x    CODESTAB_x   CODMUNCART_x  \
# count  269923.000000  269978.000000    48.000000  2.732450e+05   54065.000000
# mean        8.316894       9.179033  2435.750000  3.107655e+06  320328.673079
# std         1.734721       1.599190  1752.429869  1.940048e+06    2199.804202
# min         0.000000       0.000000     0.000000  1.250000e+02  110015.000000
# 25%         8.000000       9.000000  1446.000000  2.448637e+06  320150.000000
# 50%         8.000000       9.000000  2053.500000  2.532190e+06  320490.000000
# 75%         9.000000      10.000000  3893.000000  3.450198e+06  320520.000000
# max        99.000000      99.000000  6980.000000  9.040838e+06  530010.000000
#
#           CODMUNNASC   CODMUNNATU_x    CODMUNRES_x     CODOCUPMAE  CODPAISRES  \
# count  273807.000000  266581.000000  273807.000000  201353.000000    160317.0
# mean   320315.443323  317274.860601  320339.875555  750951.819879         1.0
# ...

# %%
df_merged_inner = pd.merge(df_sinasc_es, df_sim_es, how='inner', on = 'NUMERODN')
df_merged_inner.describe()
# Out:
#             APGAR1       APGAR5  CODCART_x    CODESTAB_x   CODMUNCART_x  \
# count  1404.000000  1405.000000        0.0  1.424000e+03     257.000000
# mean      5.730057     7.081139        NaN  3.723488e+06  320294.817121
# std       5.663572     5.591173        NaN  2.157329e+06    1868.600019
# min       0.000000     0.000000        NaN  4.520000e+02  292200.000000
# 25%       3.000000     6.000000        NaN  2.485572e+06  320490.000000
# 50%       6.000000     8.000000        NaN  2.678179e+06  320500.000000
# 75%       8.000000     9.000000        NaN  5.417139e+06  320530.000000
# max      99.000000    99.000000        NaN  7.581467e+06  320530.000000
#
#           CODMUNNASC   CODMUNNATU_x    CODMUNRES_x     CODOCUPMAE  CODPAISRES  \
# count    1438.000000    1415.000000    1438.000000    1065.000000       761.0
# mean   320724.509040  317388.977385  320360.959666  763187.969014         1.0
# std      7798.646769   18772.723060     174.465849  293811.019817         0.0
# ...

# %%
len(df_merged_inner.index)
# Out:
# 1438

# %%
df_merged_outer = pd.merge(df_sinasc_es, df_sim_es, how='outer', on = 'NUMERODN', indicator=True)
df_merged_outer.describe()
# Out:
#               APGAR1         APGAR5    CODCART_x    CODESTAB_x   CODMUNCART_x  \
# count  269923.000000  269978.000000    48.000000  2.732450e+05   54065.000000
# mean        8.316894       9.179033  2435.750000  3.107655e+06  320328.673079
# std         1.734721       1.599190  1752.429869  1.940048e+06    2199.804202
# min         0.000000       0.000000     0.000000  1.250000e+02  110015.000000
# 25%         8.000000       9.000000  1446.000000  2.448637e+06  320150.000000
# 50%         8.000000       9.000000  2053.500000  2.532190e+06  320490.000000
# 75%         9.000000      10.000000  3893.000000  3.450198e+06  320520.000000
# max        99.000000      99.000000  6980.000000  9.040838e+06  530010.000000
#
#           CODMUNNASC   CODMUNNATU_x    CODMUNRES_x     CODOCUPMAE  CODPAISRES  \
# count  273807.000000  266581.000000  273807.000000  201353.000000    160317.0
# mean   320315.443323  317274.860601  320339.875555  750951.819879         1.0
# ...

# %%
df_merged_outer.head()
# Out:
#    APGAR1  APGAR5 CODANOMAL  CODCART_x  CODESTAB_x      CODINST_x  \
# 0     8.0     9.0       NaN        NaN   2507447.0  MBA2910720001
# 1     9.0    10.0       NaN        NaN   2802112.0  MBA2913600002
# 2     9.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 3    10.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 4     8.0     9.0       NaN        NaN   2498804.0  MBA2922000001
#
#    CODMUNCART_x  CODMUNNASC  CODMUNNATU_x  CODMUNRES_x  CODOCUPMAE  \
# 0           NaN    291072.0      291630.0     320500.0         NaN
# 1           NaN    291360.0      291360.0     320520.0         NaN
# 2           NaN    292200.0      320405.0     320405.0         NaN
# 3           NaN    292200.0      320501.0     320405.0         NaN
# 4           NaN    292200.0      314430.0     320405.0         NaN
#
#    CODPAISRES  CODUFNATU  CONSPRENAT  CONSULTAS  DIFDATA_x  DTCADASTRO_x  \
# 0         1.0       29.0         4.0        3.0        4.0     1032016.0
# ...

# %%
df_merged_outer.rename(index=str, columns={"_merge": "simsim"})
# Out:
#         APGAR1  APGAR5 CODANOMAL  CODCART_x  CODESTAB_x      CODINST_x  \
# 0          8.0     9.0       NaN        NaN   2507447.0  MBA2910720001
# 1          9.0    10.0       NaN        NaN   2802112.0  MBA2913600002
# 2          9.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 3         10.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 4          8.0     9.0       NaN        NaN   2498804.0  MBA2922000001
# 5          8.0     9.0       NaN        NaN   2498804.0  MBA2922000001
# 6          7.0     8.0       NaN        NaN   2498804.0  MBA2922000001
# 7          9.0    10.0       NaN        NaN   2301008.0  MBA2931350001
# 8          8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 9          8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 10         8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 11         9.0    10.0       NaN        NaN   2102587.0  MMG3101100001
# ...

# %%
df_merged_outer
# Out:
#         APGAR1  APGAR5 CODANOMAL  CODCART_x  CODESTAB_x      CODINST_x  \
# 0          8.0     9.0       NaN        NaN   2507447.0  MBA2910720001
# 1          9.0    10.0       NaN        NaN   2802112.0  MBA2913600002
# 2          9.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 3         10.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 4          8.0     9.0       NaN        NaN   2498804.0  MBA2922000001
# 5          8.0     9.0       NaN        NaN   2498804.0  MBA2922000001
# 6          7.0     8.0       NaN        NaN   2498804.0  MBA2922000001
# 7          9.0    10.0       NaN        NaN   2301008.0  MBA2931350001
# 8          8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 9          8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 10         8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 11         9.0    10.0       NaN        NaN   2102587.0  MMG3101100001
# ...

# %% [markdown]
# # Excluindo e Encriptando listas

# %%
cols_excluded =  ['Unnamed: 0_y',
                'VERSAOSCB',
                'VERSAOSIST_y',
                 'Unnamed: 0_x']

cols_encrypted = ['CODINST',
                  'CODMUNNASC',
                  'CODMUNNATU_x',
                  'CODMUNRES_x']

# %% [markdown]
# ## Definindo qual coluna excluir/encriptar

# %%
df_merged_inner.columns
# Out:
# Index(['APGAR1', 'APGAR5', 'CODANOMAL', 'CODCART_x', 'CODESTAB_x', 'CODINST_x',
#        'CODMUNCART_x', 'CODMUNNASC', 'CODMUNNATU_x', 'CODMUNRES_x',
#        ...
#        'STDONOVA', 'TIPOBITO', 'TPMORTEOCO', 'TPNIVELINV', 'TPOBITOCOR',
#        'TPPOS', 'TPRESGINFO', 'Unnamed: 0_y', 'VERSAOSCB', 'VERSAOSIST_y'],
#       dtype='object', length=168)

# %% [markdown]
# ## Excluindo colunas

# %%
df_merged_outer.drop(cols_excluded, axis = 1)
df_merged_outer_droped = df_merged_outer.drop(cols_excluded, axis = 1)
df_merged_outer_droped
# Out:
#         APGAR1  APGAR5 CODANOMAL  CODCART_x  CODESTAB_x      CODINST_x  \
# 0          8.0     9.0       NaN        NaN   2507447.0  MBA2910720001
# 1          9.0    10.0       NaN        NaN   2802112.0  MBA2913600002
# 2          9.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 3         10.0    10.0       NaN        NaN   2506122.0  MBA2922000001
# 4          8.0     9.0       NaN        NaN   2498804.0  MBA2922000001
# 5          8.0     9.0       NaN        NaN   2498804.0  MBA2922000001
# 6          7.0     8.0       NaN        NaN   2498804.0  MBA2922000001
# 7          9.0    10.0       NaN        NaN   2301008.0  MBA2931350001
# 8          8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 9          8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 10         8.0     9.0       NaN        NaN   2102587.0  MMG3101100001
# 11         9.0    10.0       NaN        NaN   2102587.0  MMG3101100001
# ...

# %% [markdown]
# ## Encriptando colunas sensíveis

# %%
df_merged_outer_droped.
